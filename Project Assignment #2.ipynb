# %% [markdown]
# # "PROJECT TITLE"

# %% [markdown]
# March 14, 2022 Samantha Park

# %% [markdown]
# ## INTRODUCTION

# %% [markdown]
# I would like to explore the implications of racial disparities behind foundation shades. Key words in my research question will be 'race,' 'bias,' and 'foundation shades.' As someone with an interest in beauty/cosmetics and who uses foundations on a daily basis, I thought this project could be a meaningful opportunity to educate myself in the problems and biases embedded within one of the most commonly used make up product. I believe make up is a huge driver for trends and societal perception of beauty, and the lack of creativity in naming darker shades as well as the limited range in foundations shades for PoC reflect racial bias in the cosmetic and beauty industry.

# %% [markdown]
# ### Questions

# %% [markdown]
# 1. Are there any racial disparities in the range and variety of foundation shades?
# 2. How diverse is the language in labeling different shades?

# %% [markdown]
# ## METHODS

# %% [markdown]
# ### Data

# %% [markdown]
# This data was provided by the digital publication company 'The Pudding'.

# %% [markdown]
# *Include how they got the data (what is represented in the data, what's missing from the data that I think it's important)*

# %% [markdown]
# ### Terms to Know

# %% [markdown]
# **Lightness**: The lightness value from the HSL color space. This is represented as a decimal from 0 to 1 where 0 is pure black and 1 is pure white. <br>
# **Categories**: Manually assigned categories for labels of foundation shades. <br>
# **Numbers**: The numbers associated with a particular shade. <br>

# %% [markdown]
# *maybe insert photos that show how light is light?*

# %% [markdown]
# ## RESULTS

# %% [markdown]
# ### Exploring Data

# %%
import pandas as pd
import requests 
import io
import matplotlib.pyplot as plt #does this count as another python library?

# %%
url = "https://raw.githubusercontent.com/the-pudding/data/master/foundation-names/allCategories.csv" 
download = requests.get(url).content

# %%
categoriesdf = pd.read_csv(io.StringIO(download.decode('utf-8')))

# %%
url2 = "https://raw.githubusercontent.com/the-pudding/data/master/foundation-names/allShades.csv" 
download = requests.get(url2).content

# %%
shadesdf = pd.read_csv(io.StringIO(download.decode('utf-8')))

# %%
url3 = "https://raw.githubusercontent.com/the-pudding/data/master/foundation-names/allNumbers.csv"
download = requests.get(url3).content

# %%
numbersdf = pd.read_csv(io.StringIO(download.decode('utf-8')))

# %%
shadesdf
# Out:
#                         brand  \
# 0     Anastasia Beverly Hills
# 1     Anastasia Beverly Hills
# 2     Anastasia Beverly Hills
# 3     Anastasia Beverly Hills
# 4     Anastasia Beverly Hills
# ...                       ...
# 6811                  Lancôme
# 6812                  Antonym
# 6813        Benefit Cosmetics
# 6814    Urban Decay Cosmetics
# 6815             bareMinerals
#
#                                                 product  \
# 0                                   Luminous Foundation
# 1                                   Luminous Foundation
# 2                                   Luminous Foundation
# 3                                   Luminous Foundation
# 4                                   Luminous Foundation
# ...                                                 ...
# 6811  Bienfait Teinté Beauty Balm Sunscreen Broad Sp...
# 6812                 Certified Organic Baked Foundation
# 6813                   Hello Happy Soft Blur Foundation
# 6814  Naked Skin Ultra Definition Pressed Finishing ...
# 6815  bareSkin® Pure Brightening Serum Foundation Br...
#
#                                                     url  \
# 0     https://www.ulta.com/luminous-foundation?produ...
# 1     https://www.ulta.com/luminous-foundation?produ...
# 2     https://www.ulta.com/luminous-foundation?produ...
# 3     https://www.ulta.com/luminous-foundation?produ...
# 4     https://www.ulta.com/luminous-foundation?produ...
# ...                                                 ...
# 6811  https://www.sephora.com/product/bienfait-teint...
# 6812  https://www.sephora.com/product/certified-orga...
# 6813  https://www.sephora.com/product/hello-happy-so...
# 6814  https://www.sephora.com/product/naked-skin-ult...
# 6815  https://www.sephora.com/product/bareskin-pure-...
#
#                                             description  \
# 0     355N (medium skin with a neutral golden undert...
# 1        100N (very fair skin with a neutral undertone)
# 2           110C (very fair skin with a cool undertone)
# 3           120W (very fair skin with a warm undertone)
# 4     130N (very fair skin with a neutral pink under...
# ...                                                 ...
# 6811  5 Sand for medium skintones with neutral to pe...
# 6812                                    Dark - Selected
# 6813                   Shade 11 dark neutral - Selected
# 6814                              Naked Dark - Selected
# 6815                           Bare Mocha 20 - Selected
#
#                                                  imgSrc  \
# 0     https://images.ulta.com/is/image/Ulta/2551437s...
# 1     https://images.ulta.com/is/image/Ulta/2551414s...
# 2     https://images.ulta.com/is/image/Ulta/2551412s...
# 3     https://images.ulta.com/is/image/Ulta/2551419s...
# 4     https://images.ulta.com/is/image/Ulta/2551416s...
# ...                                                 ...
# 6811                 /productimages/sku/s1509348+sw.jpg
# 6812                 /productimages/sku/s1977479+sw.jpg
# 6813                 /productimages/sku/s2086551+sw.jpg
# 6814                 /productimages/sku/s1532084+sw.jpg
# 6815                 /productimages/sku/s1576883+sw.jpg
#
#                                                  imgAlt        name  specific  \
# 0     355N (medium skin with a neutral golden undert...         NaN      355N
# 1        100N (very fair skin with a neutral undertone)         NaN      100N
# 2           110C (very fair skin with a cool undertone)         NaN      110C
# 3           120W (very fair skin with a warm undertone)         NaN      120W
# 4     130N (very fair skin with a neutral pink under...         NaN      130N
# ...                                                 ...         ...       ...
# 6811                                      5 Sand 1.7 oz        Sand         5
# 6812               Dark 0.29 oz/ 8.5 g Clean at Sephora        Dark       NaN
# 6813                               Shade 11 1 oz/ 30 mL         NaN  Shade 11
# 6814                          Naked Dark 0.26 oz/ 7.3 g  Naked Dark       NaN
# 6815                                 Bare Mocha 20 1 oz  Bare Mocha        20
#
#      colorspace      hex        hue       sat  lightness
# 0           RGB  #A06F4A  25.813953  0.367521   0.458824
# 1           RGB  #F1E7DB  32.727273  0.440000   0.901961
# 2           RGB  #F0E7DB  34.285714  0.411765   0.900000
# 3           RGB  #EFD0AE  31.384615  0.670103   0.809804
# 4           RGB  #D5C1AA  32.093023  0.338583   0.750980
# ...         ...      ...        ...       ...        ...
# 6811        RGB  #D29F77  26.373626  0.502762   0.645098
# 6812        RGB  #D39C7B  22.500000  0.500000   0.654902
# 6813        RGB  #C9866E  15.824176  0.457286   0.609804
# 6814        RGB  #AF7754  23.076923  0.362550   0.507843
# 6815        RGB  #AF7357  19.090909  0.354839   0.513725
#
# [6816 rows x 13 columns]

# %%
categoriesdf
# Out:
#                       brand  \
# 0           BECCA Cosmetics
# 1           BECCA Cosmetics
# 2           BECCA Cosmetics
# 3           BECCA Cosmetics
# 4           BECCA Cosmetics
# ...                     ...
# 5302                Lancôme
# 5303                Antonym
# 5304      Benefit Cosmetics
# 5305  Urban Decay Cosmetics
# 5306           bareMinerals
#
#                                                 product  \
# 0                  Ultimate Coverage 24 Hour Foundation
# 1                  Ultimate Coverage 24 Hour Foundation
# 2                  Ultimate Coverage 24 Hour Foundation
# 3                  Ultimate Coverage 24 Hour Foundation
# 4                  Ultimate Coverage 24 Hour Foundation
# ...                                                 ...
# 5302  Bienfait Teinté Beauty Balm Sunscreen Broad Sp...
# 5303                 Certified Organic Baked Foundation
# 5304                   Hello Happy Soft Blur Foundation
# 5305  Naked Skin Ultra Definition Pressed Finishing ...
# 5306  bareSkin® Pure Brightening Serum Foundation Br...
#
#                                                     url  \
# 0     https://www.ulta.com/ultimate-coverage-24-hour...
# 1     https://www.ulta.com/ultimate-coverage-24-hour...
# 2     https://www.ulta.com/ultimate-coverage-24-hour...
# 3     https://www.ulta.com/ultimate-coverage-24-hour...
# 4     https://www.ulta.com/ultimate-coverage-24-hour...
# ...                                                 ...
# 5302  https://www.sephora.com/product/bienfait-teint...
# 5303  https://www.sephora.com/product/certified-orga...
# 5304  https://www.sephora.com/product/hello-happy-so...
# 5305  https://www.sephora.com/product/naked-skin-ult...
# 5306  https://www.sephora.com/product/bareskin-pure-...
#
#                                                  imgSrc          name  \
# 0     https://images.ulta.com/is/image/Ulta/2528173s...         shell
# 1     https://images.ulta.com/is/image/Ulta/2529033s...         linen
# 2     https://images.ulta.com/is/image/Ulta/2549910s...     alabaster
# 3     https://images.ulta.com/is/image/Ulta/2528170s...     porcelain
# 4     https://images.ulta.com/is/image/Ulta/2529037s...         ivory
# ...                                                 ...           ...
# 5302                 /productimages/sku/s1509348+sw.jpg          sand
# 5303                 /productimages/sku/s1977479+sw.jpg          dark
# 5304                 /productimages/sku/s2086551+sw.jpg  dark neutral
# 5305                 /productimages/sku/s1532084+sw.jpg    naked dark
# 5306                 /productimages/sku/s1576883+sw.jpg    bare mocha
#
#             categories  specific      hex  lightness
# 0                  gem       1W1  #EFCBA4   0.790196
# 1              textile       1N1  #F3CEB0   0.821569
# 2                  gem       1C1  #F2CBB4   0.827451
# 3                 misc       1N2  #F6C8A7   0.809804
# 4           gem, color       1C2  #F0C4AB   0.805882
# ...                ...       ...      ...        ...
# 5302              rock         5  #D29F77   0.645098
# 5303        descriptor       NaN  #D39C7B   0.654902
# 5304        descriptor  Shade 11  #C9866E   0.609804
# 5305  skin, descriptor       NaN  #AF7754   0.507843
# 5306       skin, drink        20  #AF7357   0.513725
#
# [5307 rows x 9 columns]

# %%
numbersdf
# Out:
#                   brand                                            product  \
# 0     Makeup Revolution          Conceal & Define Full Coverage Foundation
# 1             HOURGLASS                                  Veil Fluid Makeup
# 2              TOM FORD                    Traceless Soft Matte Foundation
# 3         Armani Beauty                                Neo Nude Foundation
# 4              TOM FORD                         Traceless Foundation Stick
# ...                 ...                                                ...
# 3112      Juvia's Place                              I Am Magic Foundation
# 3113            Origins  Pretty in Bloom™ SPF 20 Flower-Infused Long-We...
# 3114      Juvia's Place                              I Am Magic Foundation
# 3115            Origins  Pretty in Bloom™ SPF 20 Flower-Infused Long-We...
# 3116              Almay          Clear Complexion Make Myself Clear Makeup
#
#             name specific  lightness      hex lightToDark  numbers     id
# 0            NaN       F0   0.949020  #F2F2F2        True      0.0    1.0
# 1      Porcelain    No. 0   0.817647  #F6D3AB        True      0.0    2.0
# 2          Pearl      0.0   0.850980  #F0D8C2        True      0.0    3.0
# 3            NaN        0   0.911765  #F0E8E1        True      0.0    4.0
# 4          Pearl      0.0   0.911765  #FDE5D4        True      0.0    5.0
# ...          ...      ...        ...      ...         ...      ...    ...
# 3112        Isla      730   0.792157  #ECC4A8       False    730.0   93.0
# 3113         NaN      730   0.429412  #835E58        True    730.0  102.0
# 3114     Marisol      740   0.803922  #F2C5A8       False    740.0   93.0
# 3115         NaN      740   0.407843  #715F5F        True    740.0  102.0
# 3116  Cappuccino      900   0.360784  #904D28        True    900.0   92.0
#
# [3117 rows x 9 columns]

# %%
shadesdf.describe()
# Out:
#                hue          sat    lightness
# count  6816.000000  6816.000000  6816.000000
# mean     24.863998     0.517515     0.633914
# std       6.046594     0.161520     0.162984
# min       0.000000     0.000000     0.154902
# 25%      21.818182     0.405405     0.517647
# 50%      25.333333     0.500000     0.662745
# 75%      28.387097     0.613361     0.758824
# max     230.400000     1.000000     0.996078

# %% [markdown]
# Using this summary statistics from the shades dataset, I chose to use the lightness value of 0.66 as a point of distinction between lighter skin tones versus darker skin tones for the purpose of this project.

# %%
categoriesdf.describe()
# Out:
#          lightness
# count  5307.000000
# mean      0.634753
# std       0.164431
# min       0.154902
# 25%       0.515686
# 50%       0.664706
# 75%       0.760784
# max       0.996078

# %%
numbersdf.describe()
# Out:
#          lightness      numbers           id
# count  3117.000000  3117.000000  2991.000000
# mean      0.634527   138.628056    66.877299
# std       0.162132   169.755931    38.374610
# min       0.154902     0.000000     1.000000
# 25%       0.519608     9.000000    33.000000
# 50%       0.666667    42.500000    69.000000
# 75%       0.756863   240.000000    99.000000
# max       0.994118   900.000000   130.000000

# %%
shadesdf[shadesdf.lightness < 0.66] #shades with lightness that are below 0.66
# Out:
#                         brand  \
# 0     Anastasia Beverly Hills
# 16    Anastasia Beverly Hills
# 18    Anastasia Beverly Hills
# 19    Anastasia Beverly Hills
# 20    Anastasia Beverly Hills
# ...                       ...
# 6811                  Lancôme
# 6812                  Antonym
# 6813        Benefit Cosmetics
# 6814    Urban Decay Cosmetics
# 6815             bareMinerals
#
#                                                 product  \
# 0                                   Luminous Foundation
# 16                                  Luminous Foundation
# 18                                  Luminous Foundation
# 19                                  Luminous Foundation
# 20                                  Luminous Foundation
# ...                                                 ...
# 6811  Bienfait Teinté Beauty Balm Sunscreen Broad Sp...
# 6812                 Certified Organic Baked Foundation
# 6813                   Hello Happy Soft Blur Foundation
# 6814  Naked Skin Ultra Definition Pressed Finishing ...
# 6815  bareSkin® Pure Brightening Serum Foundation Br...
#
#                                                     url  \
# 0     https://www.ulta.com/luminous-foundation?produ...
# 16    https://www.ulta.com/luminous-foundation?produ...
# 18    https://www.ulta.com/luminous-foundation?produ...
# 19    https://www.ulta.com/luminous-foundation?produ...
# 20    https://www.ulta.com/luminous-foundation?produ...
# ...                                                 ...
# 6811  https://www.sephora.com/product/bienfait-teint...
# 6812  https://www.sephora.com/product/certified-orga...
# 6813  https://www.sephora.com/product/hello-happy-so...
# 6814  https://www.sephora.com/product/naked-skin-ult...
# 6815  https://www.sephora.com/product/bareskin-pure-...
#
#                                             description  \
# 0     355N (medium skin with a neutral golden undert...
# 16    300C (light to medium skin with a cool golden ...
# 18       310C (medium skin with a cool olive undertone)
# 19    315N (medium skin with a neutral beige undertone)
# 20     320N (medium skin with a neutral pink undertone)
# ...                                                 ...
# 6811  5 Sand for medium skintones with neutral to pe...
# 6812                                    Dark - Selected
# 6813                   Shade 11 dark neutral - Selected
# 6814                              Naked Dark - Selected
# 6815                           Bare Mocha 20 - Selected
#
#                                                  imgSrc  \
# 0     https://images.ulta.com/is/image/Ulta/2551437s...
# 16    https://images.ulta.com/is/image/Ulta/2551438s...
# 18    https://images.ulta.com/is/image/Ulta/2551597s...
# 19    https://images.ulta.com/is/image/Ulta/2551435s...
# 20    https://images.ulta.com/is/image/Ulta/2551425s...
# ...                                                 ...
# 6811                 /productimages/sku/s1509348+sw.jpg
# 6812                 /productimages/sku/s1977479+sw.jpg
# 6813                 /productimages/sku/s2086551+sw.jpg
# 6814                 /productimages/sku/s1532084+sw.jpg
# 6815                 /productimages/sku/s1576883+sw.jpg
#
#                                                  imgAlt        name  specific  \
# 0     355N (medium skin with a neutral golden undert...         NaN      355N
# 16    300C (light to medium skin with a cool golden ...         NaN      300C
# 18       310C (medium skin with a cool olive undertone)         NaN      310C
# 19    315N (medium skin with a neutral beige undertone)         NaN      315N
# 20     320N (medium skin with a neutral pink undertone)         NaN      320N
# ...                                                 ...         ...       ...
# 6811                                      5 Sand 1.7 oz        Sand         5
# 6812               Dark 0.29 oz/ 8.5 g Clean at Sephora        Dark       NaN
# 6813                               Shade 11 1 oz/ 30 mL         NaN  Shade 11
# 6814                          Naked Dark 0.26 oz/ 7.3 g  Naked Dark       NaN
# 6815                                 Bare Mocha 20 1 oz  Bare Mocha        20
#
#      colorspace      hex        hue       sat  lightness
# 0           RGB  #A06F4A  25.813953  0.367521   0.458824
# 16          RGB  #D1AA79  33.409091  0.488889   0.647059
# 18          RGB  #CB9F6D  31.914894  0.474747   0.611765
# 19          RGB  #B99371  28.333333  0.339623   0.584314
# 20          RGB  #B88C6A  26.153846  0.354545   0.568627
# ...         ...      ...        ...       ...        ...
# 6811        RGB  #D29F77  26.373626  0.502762   0.645098
# 6812        RGB  #D39C7B  22.500000  0.500000   0.654902
# 6813        RGB  #C9866E  15.824176  0.457286   0.609804
# 6814        RGB  #AF7754  23.076923  0.362550   0.507843
# 6815        RGB  #AF7357  19.090909  0.354839   0.513725
#
# [3369 rows x 13 columns]

# %% [markdown]
# ### Visualizations

# %% [markdown]
# #### 1. histogram of lightness

# %%
shadesdf['lightness'].plot(kind='hist')
plt.axvline(x=0.66, color = 'r')

# %% [markdown]
# #### 2. brands & their mean foundation shades

# %% [markdown]
# instead of mean foundation shades, i would like to change this graph into range (subtract the brand's lowest lightness shade from highest lightness shade)

# %%
w = shadesdf.groupby('brand')
w2 = w[['lightness']].mean()
w2.sort_values(by='lightness', ascending=False).plot(kind='barh', figsize=(12,20) )
# Out:
# <AxesSubplot:ylabel='brand'>

# %% [markdown]
# *feedback: it would be useful to reduce the size and/or to change the color of all bars that are greater than 0.5 so that your point can be more clearly conveyed*

# %% [markdown]
# #### 3. foundation shades & numbering system

# %%
n = numbersdf[['lightness', 'numbers']].groupby('numbers').mean()
n.plot(figsize = (40,5))
plt.axhline(y = 0.66, color = 'r') #shows how darker shades are usually the higher numbers

# %% [markdown]
# This x-axis of this plot shows the numbers that are used when labeling their shades. The y-axis of this plot shows the lightness of a shade. For example, if a brand labels its lighter shades as lower numbers and darker shades as higher numbers, that would indicate that the brand organized the shades from lighter to darker shades. As the graph shows, most of the higher numbers are used to label darker shades.

# %% [markdown]
# #### 4. scatterplot of correlation between lightness and shade numbers

# %%
numbersdf.plot(kind='scatter',
        x='lightness',
        y='numbers')
# Out:
# <AxesSubplot:xlabel='lightness', ylabel='numbers'>

# %% [markdown]
# ### Breaking down the categories

# %%
animal = categoriesdf.loc[categoriesdf['categories'].str.contains('animal')]
animal.hist(column='lightness')
# Out:
# array([[<AxesSubplot:title={'center':'lightness'}>]], dtype=object)

# %%
color = categoriesdf.loc[categoriesdf['categories'].str.contains('color')]
color.hist(column='lightness')
# Out:
# array([[<AxesSubplot:title={'center':'lightness'}>]], dtype=object)

# %%
compliment = categoriesdf.loc[categoriesdf['categories'].str.contains('compliment')]
compliment.hist(column='lightness')
# Out:
# array([[<AxesSubplot:title={'center':'lightness'}>]], dtype=object)

# %%
c = compliment[compliment.lightness < 0.66]
compliment1 = c.name.unique()
d = compliment[compliment.lightness > 0.66]
compliment2 = d.name.unique()
compliment1, compliment2
# Out:
# (array(['beautiful bronze', 'radiant honey', 'radiant sand',
#         'classic beige', 'classic tan', 'classic tan/cappuccino',
#         'classic ivory', 'pure beige', 'radiant sun', 'gratitude',
#         'harmony', 'honest', 'honour', 'intuitive', 'joy', 'kind',
#         'legendary', 'loveable', 'magical', 'masterful', 'powerful',
#         'soulful', 'spirited', 'strong', 'warrior', 'wise', 'reverent',
#         'unstoppable'], dtype=object),
#  array(['classic ivory', 'classic beige', 'perfect beige', 'radiant',
#         'pure beige', 'radiant honey', 'classic alabaster', 'amazing',
#         'beautiful', 'brave', 'bright', 'brilliant', 'charismatic',
#         'creative', 'daring', 'determined', 'energetic', 'fabulous',
#         'fearless', 'generous', 'geniune', 'gifted', 'glorious', 'grace',
#         'radiant tan', 'dynamic', 'mystical', 'juicy', 'classic', 'pure',
#         'timeless'], dtype=object))

# %%
c.count(), d.count()
# Out:
# (brand         47
#  product       47
#  url           47
#  imgSrc        47
#  name          47
#  categories    47
#  specific      25
#  hex           47
#  lightness     47
#  dtype: int64,
#  brand         50
#  product       50
#  url           50
#  imgSrc        50
#  name          50
#  categories    50
#  specific      32
#  hex           50
#  lightness     50
#  dtype: int64)

# %%
descriptor = categoriesdf.loc[categoriesdf['categories'].str.contains('descriptor')]
descriptor.hist(column='lightness')
# Out:
# array([[<AxesSubplot:title={'center':'lightness'}>]], dtype=object)

# %%
drink = categoriesdf.loc[categoriesdf['categories'].str.contains('drink')]
drink.hist(column='lightness')
# Out:
# array([[<AxesSubplot:title={'center':'lightness'}>]], dtype=object)

# %% [markdown]
# The graphs shows a noticeablely high freqency for drink-categorized names for darker shades.

# %%
a = drink[drink.lightness < 0.66]
drinktype1 = a.name.unique()
b = drink[drink.lightness > 0.66]
drinktype2 = b.name.unique()
drinktype1, drinktype2
# Out:
# (array(['café', 'mocha', 'espresso', 'chai', 'spice rum', 'cappuccino',
#         'suede mocha', 'java', 'coffee', 'light espresso', 'dark espresso',
#         'latte', 'cognac', 'rich mocha', 'rich java', 'expresso',
#         'cream beige', 'creamy natural', 'creme cafe', 'spiced latte',
#         'hot chocolate', 'café brown', 'classic tan/cappuccino',
#         'spiced rum', 'crème café', 'creamy vanilla', 'creamy tan',
#         'creamy cocoa', 'cafe au lait', 'soft chai', 'toasted chai',
#         'warm mocha', 'nude mocha', 'deep espresso', 'hint of cappuccino',
#         'hint of mocha', 'hint of espresso', 'espresso beige',
#         'latte macchiato beige', 'deep mocha', 'neutral champagne',
#         'cool chai', 'rich espresso', 'intense java', 'coffee bean', 'tea',
#         'macchiato', 'tan café latte', 'light cream', 'neutral mocha',
#         'mocha spice', 'mocha java', 'cool espresso', 'warm coffee',
#         'brandy', 'light mocha', 'silk brandy', 'bare mocha'], dtype=object),
#  array(['crème', 'latte', 'chai', 'cappucino', 'cream', 'creamy nude',
#         'creamy vanilla', 'creamy natural', 'matte cream', 'cream ivory',
#         'tea', 'buttermilk', 'creamy beige', 'hint of crème',
#         'hint of latte', 'cream beige', 'pink cream', 'light cream',
#         'peach cream', 'milkshake', 'macchiato', 'milk', 'champagne',
#         'cool milk', 'milky peach'], dtype=object))

# %% [markdown]
# a lot of 'mocha', 'espresso'

# %%
a.count(), b.count()
# Out:
# (brand         215
#  product       215
#  url           215
#  imgSrc        215
#  name          215
#  categories    215
#  specific      126
#  hex           215
#  lightness     215
#  dtype: int64,
#  brand         63
#  product       63
#  url           63
#  imgSrc        63
#  name          63
#  categories    63
#  specific      28
#  hex           63
#  lightness     63
#  dtype: int64)

# %%
food = categoriesdf.loc[categoriesdf['categories'].str.contains('food')]
food.hist(column='lightness')
# Out:
# array([[<AxesSubplot:title={'center':'lightness'}>]], dtype=object)

# %%
gem = categoriesdf.loc[categoriesdf['categories'].str.contains('gem')]
gem.hist(column='lightness')
# Out:
# array([[<AxesSubplot:title={'center':'lightness'}>]], dtype=object)

# %%
e = gem[gem.lightness < 0.66]
gem1 = e.name.unique()
f = gem[gem.lightness > 0.66]
gem2 = f.name.unique()
gem1, gem2
# Out:
# (array(['amber', 'true ivory', 'golden amber', 'truly topaz',
#         'natural amber', 'deep amber', 'amber honey', 'amber beige',
#         'shell beige', 'fresh amber', 'ivory beige', 'classic ivory',
#         'ivory rose', 'black pearl', 'warm ivory', 'warm amber',
#         'rich amber', 'neutral amber', 'cool amber', 'golden ivory',
#         'cool ivory', 'jasper', 'obsidian', 'neutral ivory', 'sunny amber',
#         'citrine', 'intense ivory'], dtype=object),
#  array(['shell', 'alabaster', 'ivory', 'ivoire', 'seashell', 'pearl',
#         'light ivory', 'golden ivory', 'classic ivory', 'natural ivory',
#         'neutral ivory', 'fair ivory', 'warm ivory', 'ivory buff',
#         'matte ivory', 'opal', 'amber', 'pale ivory', 'ivory nude',
#         'cool bone', 'ivory beige', 'shell beige', 'shell bisque',
#         'shell ivory', 'soft ivory', 'nude ivory', 'rose ivory',
#         'fresh ivory', 'cream ivory', 'bone', 'fresh alabaster',
#         'porcelain ivory', 'soft ivory/classic ivory', 'true alabaster',
#         'fairy ivory', 'rose pearl', 'beige ivory', 'white pearl',
#         'classic alabaster', 'cool shell', 'warm shell', 'golden shell',
#         'hint of ivory', 'pink alabaster', 'yellow alabaster', 'marble',
#         'amber honey', 'cool ivory', 'ivory silk', 'ivory rose', 'quartz',
#         'citrine', 'topaz', 'vanille ivory', 'medium ivory', 'cool amber',
#         'deep golden amber', 'rosy ivory', 'amber wram', 'amber cool',
#         'abundant alabaster', 'lightest alabaster', 'silk shell'],
#        dtype=object))

# %%
e.count(), f.count()
# Out:
# (brand         92
#  product       92
#  url           92
#  imgSrc        92
#  name          92
#  categories    92
#  specific      58
#  hex           92
#  lightness     92
#  dtype: int64,
#  brand         360
#  product       360
#  url           360
#  imgSrc        360
#  name          360
#  categories    360
#  specific      217
#  hex           360
#  lightness     360
#  dtype: int64)

# %%
location = categoriesdf.loc[categoriesdf['categories'].str.contains('location')]
location.hist(column='lightness')
# Out:
# array([[<AxesSubplot:title={'center':'lightness'}>]], dtype=object)

# %%
h = location[location.lightness < 0.66]
location1 = h.name.unique()
i = location[location.lightness > 0.66]
location2 = i.name.unique()
location1, location2
# Out:
# (array(['tonka', 'syracuse', 'tahoe', 'moorea', 'huahine', 'cadiz',
#         'caracas', 'belem', 'macao', 'marquises', 'manaus',
#         'new caledonia', 'iguacu', 'namibia', 'zambie', 'mali', 'valencia',
#         'aruba', 'kalahari sand', 'lucia', 'mallorca', 'kapua', 'mumbai',
#         'cali', 'punaluu', 'goa', 'sudan', 'senegal', 'chad', 'angola',
#         'kano', 'kenya', 'tanzania', 'togo', 'dakar', 'malawi', 'lagos',
#         'gabon', 'burkina', 'zaria', 'accra', 'kampala', 'somalia',
#         'ethiopia', 'nairobi', 'havana', 'rio', 'punta cana', 'savanna',
#         'casablanca', 'bogota', 'tangier', 'giza', 'matira', 'kokkini',
#         'dominica', 'porto covo', 'pavones', 'miho', 'roque', 'zambia',
#         'barcelona', 'vanuatu', 'stromboli', 'malaga', 'seychelles',
#         'polynesia', 'cuzco', 'bonaire', 'martinique', 'kapiti',
#         'macquarie', 'macassar', 'new guinea', 'trinidad', 'new orleans',
#         'benares', 'khartoum', 'newport', 'la jolla'], dtype=object),
#  array(['oslo', 'siberia', 'mont blanc', 'yukon', 'gobi', 'salzburg',
#         'deauville', 'vienna', 'fiji', 'punjab', 'patagonia', 'vallauris',
#         'santa fe', 'sahel', 'stromboli', 'vanuatu', 'barcelona',
#         'valencia', 'aruba', 'moorea', 'cadiz', 'biscay', 'seville',
#         'lucerne', 'marino', 'aspen', 'riviera', 'ibiza', 'martinique',
#         'cairo', 'cebu', 'fes', 'capri', 'malta', 'maricao', 'bali',
#         'isla', 'marisol', 'tulum', 'balos', 'formosa', 'paloma',
#         'porto ferro', 'kamari', 'vallaurius', 'finland', 'alaska',
#         'terre neuve', 'st moritz', 'groenland', 'formentera', 'mallorca',
#         'tavarua', 'corsica', 'bowen', 'salina', 'chios', 'catalina',
#         'milos', 'bedarra', 'maraca', 'montserrat', 'tahoe', 'kalahari',
#         'mesa', 'mojave', 'arizona', 'venice', 'manhattan beach'],
#        dtype=object))

# %%
metal = categoriesdf.loc[categoriesdf['categories'].str.contains('metal')]
metal.hist(column='lightness')
# Out:
# array([[<AxesSubplot:title={'center':'lightness'}>]], dtype=object)

# %%
j = metal[metal.lightness < 0.66]
metal1 = j.name.unique()
k = metal[metal.lightness > 0.66]
metal2 = k.name.unique()
metal1, metal2
# Out:
# (array(['bronze', 'deep bronze', 'beautiful bronze', 'copper',
#         'bronze beige', 'golden bronze', 'honey bronze', 'bronze venus',
#         'warm bronze', 'dore', 'tan café latte', 'tan bronze',
#         'cool copper', 'gold'], dtype=object),
#  array(['honey bronze', 'bronze', 'bronzed beige', 'bronze beige',
#         'dore medium', 'dore', 'bronzed'], dtype=object))

# %%
j.count(), k.count()
# Out:
# (brand         54
#  product       54
#  url           54
#  imgSrc        54
#  name          54
#  categories    54
#  specific      43
#  hex           54
#  lightness     54
#  dtype: int64,
#  brand         9
#  product       9
#  url           9
#  imgSrc        9
#  name          9
#  categories    9
#  specific      4
#  hex           9
#  lightness     9
#  dtype: int64)

# %%
misc = categoriesdf.loc[categoriesdf['categories'].str.contains('misc')]
misc.hist(column='lightness')
# Out:
# array([[<AxesSubplot:title={'center':'lightness'}>]], dtype=object)

# %%
name = categoriesdf.loc[categoriesdf['categories'].str.contains('name')]
name.hist(column='lightness')
# Out:
# array([[<AxesSubplot:title={'center':'lightness'}>]], dtype=object)

# %%
plant = categoriesdf.loc[categoriesdf['categories'].str.contains('plant')]
plant.hist(column='lightness')
# Out:
# array([[<AxesSubplot:title={'center':'lightness'}>]], dtype=object)

# %%
rock = categoriesdf.loc[categoriesdf['categories'].str.contains('rock')]
rock.hist(column='lightness')
# Out:
# array([[<AxesSubplot:title={'center':'lightness'}>]], dtype=object)

# %%
skin = categoriesdf.loc[categoriesdf['categories'].str.contains('skin')]
skin.hist(column='lightness')
# Out:
# array([[<AxesSubplot:title={'center':'lightness'}>]], dtype=object)

# %%
textile = categoriesdf.loc[categoriesdf['categories'].str.contains('textile')]
textile.hist(column='lightness')
# Out:
# array([[<AxesSubplot:title={'center':'lightness'}>]], dtype=object)

# %%
wood = categoriesdf.loc[categoriesdf['categories'].str.contains('wood')]
wood.hist(column='lightness')
# Out:
# array([[<AxesSubplot:title={'center':'lightness'}>]], dtype=object)

# %%
m = wood[wood.lightness < 0.66]
wood1 = m.name.unique()
n = wood[wood.lightness > 0.66]
wood2 = m.name.unique()
wood1, wood2
# Out:
# (array(['bamboo', 'maple', 'walnut', 'mahogany', 'black walnut',
#         'ebony brown', 'sandalwood', 'oak', 'cedar', 'rich mahogany',
#         'deep ebony', 'ebony', 'rich ebony', 'deep maple', 'warm mahogany',
#         'mahogany golden', 'warm walnut', 'deep walnut', 'warm bamboo',
#         'cool ebony', 'deep dark ebony', 'golden walnut', 'medium walnut',
#         'cool walnut', 'neutral walnut', 'teak', 'mahhogany', 'rosewood',
#         'silk maple'], dtype=object),
#  array(['bamboo', 'maple', 'walnut', 'mahogany', 'black walnut',
#         'ebony brown', 'sandalwood', 'oak', 'cedar', 'rich mahogany',
#         'deep ebony', 'ebony', 'rich ebony', 'deep maple', 'warm mahogany',
#         'mahogany golden', 'warm walnut', 'deep walnut', 'warm bamboo',
#         'cool ebony', 'deep dark ebony', 'golden walnut', 'medium walnut',
#         'cool walnut', 'neutral walnut', 'teak', 'mahhogany', 'rosewood',
#         'silk maple'], dtype=object))

# %%
m.count(), n.count()
# Out:
# (brand         142
#  product       142
#  url           142
#  imgSrc        142
#  name          142
#  categories    142
#  specific       78
#  hex           142
#  lightness     142
#  dtype: int64,
#  brand         37
#  product       37
#  url           37
#  imgSrc        37
#  name          37
#  categories    37
#  specific      31
#  hex           37
#  lightness     37
#  dtype: int64)

# %% [markdown]
# ### Analysis

# %%
numbersdf[['lightness','numbers']].corr()
# Out:
#            lightness   numbers
# lightness   1.000000 -0.259673
# numbers    -0.259673  1.000000

# %% [markdown]
# There is a weak negative correlation between 'lightness' and 'numbers', which somewhat confirms that the higher the lightness, the lower the number used to label the shade. However, it is not strong enough of a correlation to conclude there is a definite trend in which lighter shades are labeled first.

# %%
categories = categoriesdf.groupby('categories').size()
categories.sort_values(ascending=False) 
#descriptor, food, color, location, drink one of the most common words in foundation shade names
# Out:
# categories
# descriptor                       1322
# food                              682
# descriptor, color                 250
# location                          210
# drink                             206
#                                  ...
# misc, skin, color, compliment       1
# plant, color, food                  1
# plant, color, gem                   1
# sand                                1
# wood, descriptor                    1
# Length: 128, dtype: int64

# %%
descriptorcategories = categoriesdf.loc[categoriesdf['categories'].str.contains('descriptor')]
descriptorcategories[descriptorcategories.lightness>0.66]
# Out:
#                   brand                                            product  \
# 42    Benefit Cosmetics  Hello Happy Flawless Brightening Foundation SP...
# 43    Benefit Cosmetics  Hello Happy Flawless Brightening Foundation SP...
# 44    Benefit Cosmetics  Hello Happy Flawless Brightening Foundation SP...
# 45    Benefit Cosmetics  Hello Happy Flawless Brightening Foundation SP...
# 46    Benefit Cosmetics  Hello Happy Flawless Brightening Foundation SP...
# ...                 ...                                                ...
# 5267           Shiseido                                  Sports BB SPF 50+
# 5268           Shiseido                                  Sports BB SPF 50+
# 5282            Antonym              Skin Esteem Organic Liquid Foundation
# 5283            Antonym              Skin Esteem Organic Liquid Foundation
# 5284            Antonym              Skin Esteem Organic Liquid Foundation
#
#                                                     url  \
# 42    https://www.ulta.com/hello-happy-flawless-brig...
# 43    https://www.ulta.com/hello-happy-flawless-brig...
# 44    https://www.ulta.com/hello-happy-flawless-brig...
# 45    https://www.ulta.com/hello-happy-flawless-brig...
# 46    https://www.ulta.com/hello-happy-flawless-brig...
# ...                                                 ...
# 5267  https://www.sephora.com/product/sports-bb-spf-...
# 5268  https://www.sephora.com/product/sports-bb-spf-...
# 5282  https://www.sephora.com/product/skin-esteem-or...
# 5283  https://www.sephora.com/product/skin-esteem-or...
# 5284  https://www.sephora.com/product/skin-esteem-or...
#
#                                                  imgSrc  \
# 42    https://images.ulta.com/is/image/Ulta/2547818s...
# 43    https://images.ulta.com/is/image/Ulta/2547823s...
# 44    https://images.ulta.com/is/image/Ulta/2547822s...
# 45    https://images.ulta.com/is/image/Ulta/2547831s...
# 46    https://images.ulta.com/is/image/Ulta/2547830s...
# ...                                                 ...
# 5267                 /productimages/sku/s2219673+sw.jpg
# 5268                 /productimages/sku/s2219681+sw.jpg
# 5282                 /productimages/sku/s2016251+sw.jpg
# 5283                 /productimages/sku/s2016269+sw.jpg
# 5284                 /productimages/sku/s2016277+sw.jpg
#
#                              name         categories specific      hex  \
# 42                      fair cool         descriptor  Shade 1  #EACFB7
# 43                     light warm         descriptor  Shade 2  #F7D3B3
# 44             light neutral warm         descriptor  Shade 3  #E9C7A4
# 45                 medium neutral         descriptor  Shade 4  #D0B099
# 46    shade   medium neutral warm         descriptor        5  #DCB590
# ...                           ...                ...      ...      ...
# 5267                       medium         descriptor      NaN  #F4C9A0
# 5268                         dark         descriptor       50  #F4C9A0
# 5282                  beige light  color, descriptor      NaN  #EBC5B0
# 5283           beige medium light  color, descriptor      NaN  #E4BFB1
# 5284                 beige medium  color, descriptor      NaN  #D5B1A1
#
#       lightness
# 42     0.817647
# 43     0.835294
# 44     0.778431
# 45     0.707843
# 46     0.713725
# ...         ...
# 5267   0.792157
# 5268   0.792157
# 5282   0.805882
# 5283   0.794118
# 5284   0.733333
#
# [1269 rows x 9 columns]

# %%
lowerhalfshade = categoriesdf[categoriesdf.lightness <= 0.66]
lowerhalfshade
# Out:
#                       brand  \
# 14          BECCA Cosmetics
# 15          BECCA Cosmetics
# 18          BECCA Cosmetics
# 19          BECCA Cosmetics
# 20          BECCA Cosmetics
# ...                     ...
# 5302                Lancôme
# 5303                Antonym
# 5304      Benefit Cosmetics
# 5305  Urban Decay Cosmetics
# 5306           bareMinerals
#
#                                                 product  \
# 14                 Ultimate Coverage 24 Hour Foundation
# 15                 Ultimate Coverage 24 Hour Foundation
# 18                 Ultimate Coverage 24 Hour Foundation
# 19                 Ultimate Coverage 24 Hour Foundation
# 20                 Ultimate Coverage 24 Hour Foundation
# ...                                                 ...
# 5302  Bienfait Teinté Beauty Balm Sunscreen Broad Sp...
# 5303                 Certified Organic Baked Foundation
# 5304                   Hello Happy Soft Blur Foundation
# 5305  Naked Skin Ultra Definition Pressed Finishing ...
# 5306  bareSkin® Pure Brightening Serum Foundation Br...
#
#                                                     url  \
# 14    https://www.ulta.com/ultimate-coverage-24-hour...
# 15    https://www.ulta.com/ultimate-coverage-24-hour...
# 18    https://www.ulta.com/ultimate-coverage-24-hour...
# 19    https://www.ulta.com/ultimate-coverage-24-hour...
# 20    https://www.ulta.com/ultimate-coverage-24-hour...
# ...                                                 ...
# 5302  https://www.sephora.com/product/bienfait-teint...
# 5303  https://www.sephora.com/product/certified-orga...
# 5304  https://www.sephora.com/product/hello-happy-so...
# 5305  https://www.sephora.com/product/naked-skin-ult...
# 5306  https://www.sephora.com/product/bareskin-pure-...
#
#                                                  imgSrc          name  \
# 14    https://images.ulta.com/is/image/Ulta/2549922s...         camel
# 15    https://images.ulta.com/is/image/Ulta/2528177s...      noisette
# 18    https://images.ulta.com/is/image/Ulta/2549916s...       cassava
# 19    https://images.ulta.com/is/image/Ulta/2549920s...         khaki
# 20    https://images.ulta.com/is/image/Ulta/2528167s...         olive
# ...                                                 ...           ...
# 5302                 /productimages/sku/s1509348+sw.jpg          sand
# 5303                 /productimages/sku/s1977479+sw.jpg          dark
# 5304                 /productimages/sku/s2086551+sw.jpg  dark neutral
# 5305                 /productimages/sku/s1532084+sw.jpg    naked dark
# 5306                 /productimages/sku/s1576883+sw.jpg    bare mocha
#
#             categories  specific      hex  lightness
# 14       color, animal       3N1  #D59C79   0.654902
# 15                food       3N2  #D49971   0.637255
# 18               plant       3C2  #D29B7B   0.652941
# 19             textile       3N3  #CE9770   0.623529
# 20         color, food       3W3  #CC9A70   0.619608
# ...                ...       ...      ...        ...
# 5302              rock         5  #D29F77   0.645098
# 5303        descriptor       NaN  #D39C7B   0.654902
# 5304        descriptor  Shade 11  #C9866E   0.609804
# 5305  skin, descriptor       NaN  #AF7754   0.507843
# 5306       skin, drink        20  #AF7357   0.513725
#
# [2600 rows x 9 columns]

# %%
a = lowerhalfshade.groupby('categories').size()
a.sort_values(ascending=False)
# Out:
# categories
# descriptor                612
# food                      444
# drink                     166
# descriptor, food          130
# wood                      111
#                          ...
# misc, drink                 1
# misc, food, compliment      1
# sand                        1
# misc, rock                  1
# wood, descriptor            1
# Length: 96, dtype: int64

# %%
upperhalfshade = categoriesdf[categoriesdf.lightness > 0.66]
upperhalfshade
# Out:
#                 brand                                      product  \
# 0     BECCA Cosmetics         Ultimate Coverage 24 Hour Foundation
# 1     BECCA Cosmetics         Ultimate Coverage 24 Hour Foundation
# 2     BECCA Cosmetics         Ultimate Coverage 24 Hour Foundation
# 3     BECCA Cosmetics         Ultimate Coverage 24 Hour Foundation
# 4     BECCA Cosmetics         Ultimate Coverage 24 Hour Foundation
# ...               ...                                          ...
# 5282          Antonym        Skin Esteem Organic Liquid Foundation
# 5283          Antonym        Skin Esteem Organic Liquid Foundation
# 5284          Antonym        Skin Esteem Organic Liquid Foundation
# 5285          Antonym        Skin Esteem Organic Liquid Foundation
# 5290         Clinique  Superbalanced Silk Makeup Broad Spectrum 15
#
#                                                     url  \
# 0     https://www.ulta.com/ultimate-coverage-24-hour...
# 1     https://www.ulta.com/ultimate-coverage-24-hour...
# 2     https://www.ulta.com/ultimate-coverage-24-hour...
# 3     https://www.ulta.com/ultimate-coverage-24-hour...
# 4     https://www.ulta.com/ultimate-coverage-24-hour...
# ...                                                 ...
# 5282  https://www.sephora.com/product/skin-esteem-or...
# 5283  https://www.sephora.com/product/skin-esteem-or...
# 5284  https://www.sephora.com/product/skin-esteem-or...
# 5285  https://www.sephora.com/product/skin-esteem-or...
# 5290  https://www.sephora.com/product/superbalanced-...
#
#                                                  imgSrc                name  \
# 0     https://images.ulta.com/is/image/Ulta/2528173s...               shell
# 1     https://images.ulta.com/is/image/Ulta/2529033s...               linen
# 2     https://images.ulta.com/is/image/Ulta/2549910s...           alabaster
# 3     https://images.ulta.com/is/image/Ulta/2528170s...           porcelain
# 4     https://images.ulta.com/is/image/Ulta/2529037s...               ivory
# ...                                                 ...                 ...
# 5282                 /productimages/sku/s2016251+sw.jpg         beige light
# 5283                 /productimages/sku/s2016269+sw.jpg  beige medium light
# 5284                 /productimages/sku/s2016277+sw.jpg        beige medium
# 5285                 /productimages/sku/s2016293+sw.jpg                 tan
# 5290                 /productimages/sku/s1841576+sw.jpg          silk shell
#
#              categories specific      hex  lightness
# 0                   gem      1W1  #EFCBA4   0.790196
# 1               textile      1N1  #F3CEB0   0.821569
# 2                   gem      1C1  #F2CBB4   0.827451
# 3                  misc      1N2  #F6C8A7   0.809804
# 4            gem, color      1C2  #F0C4AB   0.805882
# ...                 ...      ...      ...        ...
# 5282  color, descriptor      NaN  #EBC5B0   0.805882
# 5283  color, descriptor      NaN  #E4BFB1   0.794118
# 5284  color, descriptor      NaN  #D5B1A1   0.733333
# 5285        skin, color      NaN  #CBA28F   0.678431
# 5290       textile, gem      NaN  #F0C3B2   0.819608
#
# [2707 rows x 9 columns]

# %%
b = upperhalfshade.groupby('categories').size()
b.sort_values(ascending=False)
# Out:
# categories
# descriptor            710
# food                  238
# descriptor, color     167
# misc                  155
# gem, color            120
#                      ...
# food, drink             1
# misc, plant             1
# misc, plant, color      1
# food, plant             1
# plant, color, food      1
# Length: 98, dtype: int64

# %%
uppercomplimentfreq = upperhalfshade[upperhalfshade['categories'].str.contains('compliment')]
uppercomplimentfreq #81 counts
# Out:
#              brand                                            product  \
# 504      CoverGirl              TruBlend Matte Made Liquid Foundation
# 509      CoverGirl              TruBlend Matte Made Liquid Foundation
# 517      CoverGirl              TruBlend Matte Made Liquid Foundation
# 632     Maybelline          SuperStay Full Coverage Powder Foundation
# 1100  jane iredale         PurePressed Base Mineral Foundation Refill
# 1165     CoverGirl                     Olay Simply Ageless Foundation
# 1168     CoverGirl                     Olay Simply Ageless Foundation
# 1186  Estée Lauder  Double Wear Stay In Place Matte Powder Foundation
# 1232    Wet n Wild                        PhotoFocus Stick Foundation
# 1419       L'Oréal       True Match Super-Blendable Foundation Makeup
# 1570    Maybelline                    Fit Me Dewy + Smooth Foundation
# 1579    Maybelline                    Fit Me Dewy + Smooth Foundation
# 1581    Maybelline                    Fit Me Dewy + Smooth Foundation
# 1687    Maybelline          Fit Me Matte + Poreless Liquid Foundation
# 1697    Maybelline          Fit Me Matte + Poreless Liquid Foundation
# 1725       L'Oréal    Infallible Pro-Matte Liquid Longwear Foundation
# 1802       L'Oréal                     Infallible Pro-Glow Foundation
# 1816     CoverGirl            Simply Ageless 3-In-1 Liquid Foundation
# 2103    Maybelline                Super Stay Full Coverage Foundation
# 2140       L'Oréal              Infallible Fresh Wear 24HR Foundation
# 2416    Maybelline  Dream Urban Cover Flawless Coverage Foundation...
# 2522        Milani                            Screen Queen Foundation
# 2600    Maybelline                    Dream Radiant Liquid Foundation
# 2604    Maybelline                    Dream Radiant Liquid Foundation
# 2858  jane iredale                       Liquid Minerals A Foundation
# 2933         ZOEVA         Authentik Skin Natural Luminous Foundation
# 2935         ZOEVA         Authentik Skin Natural Luminous Foundation
# 2936         ZOEVA         Authentik Skin Natural Luminous Foundation
# 2937         ZOEVA         Authentik Skin Natural Luminous Foundation
# 2938         ZOEVA         Authentik Skin Natural Luminous Foundation
# 2939         ZOEVA         Authentik Skin Natural Luminous Foundation
# 2940         ZOEVA         Authentik Skin Natural Luminous Foundation
# 2941         ZOEVA         Authentik Skin Natural Luminous Foundation
# 2942         ZOEVA         Authentik Skin Natural Luminous Foundation
# 2943         ZOEVA         Authentik Skin Natural Luminous Foundation
# 2944         ZOEVA         Authentik Skin Natural Luminous Foundation
# 2946         ZOEVA         Authentik Skin Natural Luminous Foundation
# 2948         ZOEVA         Authentik Skin Natural Luminous Foundation
# 2949         ZOEVA         Authentik Skin Natural Luminous Foundation
# 2950         ZOEVA         Authentik Skin Natural Luminous Foundation
# 2951         ZOEVA         Authentik Skin Natural Luminous Foundation
# 2952         ZOEVA         Authentik Skin Natural Luminous Foundation
# 3153  Estée Lauder   Futurist Hydra Rescue Moisturizing Makeup SPF 45
# 4624       Lancôme         SKIN FEELS GOOD Skin Nourishing Foundation
# 4883   Josie Maran                Vibrancy Argan Oil Foundation Fluid
# 4885   Josie Maran                Vibrancy Argan Oil Foundation Fluid
# 4886   Josie Maran                Vibrancy Argan Oil Foundation Fluid
# 5271      lilah b.                  Marvelous Matte™ Crème Foundation
# 5272      lilah b.                  Marvelous Matte™ Crème Foundation
# 5273      lilah b.                  Marvelous Matte™ Crème Foundation
#
#                                                     url  \
# 504   https://www.ulta.com/trublend-matte-made-liqui...
# 509   https://www.ulta.com/trublend-matte-made-liqui...
# 5273                 /productimages/sku/s2143683+sw.jpg           timeless
#
#                          categories specific      hex  lightness
# 504          gem, color, compliment      L40  #DAB197   0.723529
# 509               color, compliment      L90  #E4B292   0.733333
# 517         misc, color, compliment      M90  #D2AC88   0.678431
# 632          gem, color, compliment      NaN  #F1E6D4   0.888235
# 1100               misc, compliment      NaN  #E7C4A4   0.774510
# 1165         gem, color, compliment      210  #EAC9AA   0.792157
# 1168              color, compliment      230  #E9C7AE   0.798039
# 1186        misc, color, compliment      2C1  #FCDBB7   0.852941
# 1232         gem, color, compliment      NaN  #ECB682   0.717647
# 1419         gem, color, compliment      NaN  #D8B59C   0.729412
# 1570         gem, color, compliment      NaN  #FDFBF9   0.984314
# 1579        misc, color, compliment      NaN  #FDFCFB   0.988235
# 1581              color, compliment      NaN  #FBFBFB   0.984314
# 1687         gem, color, compliment      120  #EDCAB4   0.817647
# 1697        misc, color, compliment      235  #EBBFA7   0.788235
# 1725         gem, color, compliment      101  #F7C2A3   0.803922
# 1802         gem, color, compliment      NaN  #FCDAD4   0.909804
# 1816         gem, color, compliment      NaN  #E8BFA1   0.770588
# 2103         gem, color, compliment      120  #E0BD9B   0.743137
# 2140         misc, food, compliment      NaN  #D5A67E   0.664706
# 2416         gem, color, compliment      NaN  #E3D1B8   0.805882
# 2522                gem, compliment      NaN  #FBE9DB   0.921569
# 2600         gem, color, compliment      NaN  #F0D1B5   0.825490
# 2604        misc, color, compliment      NaN  #E5C099   0.749020
# 2858               misc, compliment      NaN  #ECCCB3   0.813725
# 2933               misc, compliment     020C  #EACFB9   0.821569
# 2935               misc, compliment     050N  #E1BE9E   0.750980
# 2936               misc, compliment     060N  #E7BD9A   0.754902
# 2937               misc, compliment     070N  #E8BA91   0.739216
# 2938               misc, compliment     080W  #E7BA97   0.749020
# 2939               misc, compliment     090C  #E5BEA2   0.766667
# 2940               misc, compliment     110N  #E2B590   0.725490
# 2941               misc, compliment     120N  #E9BE97   0.752941
# 2942               misc, compliment     130C  #E7B894   0.743137
# 2943               misc, compliment     140N  #E9BD95   0.749020
# 2944               misc, compliment     150C  #E9B98F   0.737255
# 2946               misc, compliment     170W  #E8B88C   0.729412
# 2948               misc, compliment     190N  #E3B284   0.703922
# 2949               misc, compliment     200W  #E8B37E   0.701961
# 2950               misc, compliment     210N  #DDA278   0.668627
# 2951               misc, compliment     220W  #E7A87D   0.698039
# 2952               misc, compliment     230W  #E6A470   0.670588
# 3153        misc, color, compliment      2C1  #CFAF9C   0.711765
# 4624  misc, skin, color, compliment      05N  #D8A38D   0.700000
# 4883               misc, compliment      RG5  #E7CAC0   0.829412
# 4885               misc, compliment     RG30  #D5B19F   0.729412
# 4886               misc, compliment     RG50  #CBAE9F   0.709804
# 5271               misc, compliment      NaN  #D5AA92   0.703922
# 5272               misc, compliment      NaN  #CDA394   0.692157
# 5273               misc, compliment      NaN  #C7A395   0.682353

# %%
lowercomplimentfreq = lowerhalfshade[lowerhalfshade['categories'].str.contains('compliment')]
lowercomplimentfreq #16 counts ==> noticeably less than shade names of shades that are lighter
# 601         beautiful bronze         misc, compliment, metal      NaN
# 614         beautiful bronze         misc, compliment, metal      NaN
# 624         beautiful bronze         misc, compliment, metal      NaN
# 962            radiant honey          misc, food, compliment      NaN
# 963             radiant sand          misc, rock, compliment      NaN
# 1235           classic beige               color, compliment      NaN
# 1257             classic tan         skin, color, compliment      NaN
# 1407           classic beige               color, compliment      NaN
# 1430           classic beige               color, compliment      NaN
# 1435             classic tan         skin, color, compliment      NaN
# 1606  classic tan/cappuccino  skin, color, drink, compliment      NaN
# 1608           classic beige               color, compliment      NaN
# 1707             classic tan         skin, color, compliment      335
# 1708           classic beige               color, compliment      245
# 1737             classic tan         skin, color, compliment      109
# 1811             classic tan         skin, color, compliment      NaN
# 1826             classic tan         skin, color, compliment      NaN
# 1920           classic ivory          gem, color, compliment      NaN
# 1933           classic beige               color, compliment      NaN
# 2022             classic tan         skin, color, compliment      NaN
# 2054              pure beige         misc, color, compliment      2C1
# 2142            radiant sand          misc, rock, compliment      NaN
# 2144             radiant sun                misc, compliment      NaN
# 2688             classic tan         skin, color, compliment      NaN
# 2789             classic tan         skin, color, compliment       M3
# 2887             classic tan         skin, color, compliment      NaN
# 2953               gratitude                misc, compliment     240N
# 2955                 harmony                misc, compliment     260W
# 2956                  honest                misc, compliment     270N
# 2957                  honour                misc, compliment     280N
# 2958               intuitive                misc, compliment     290W
# 2959                     joy                misc, compliment     300N
# 2960                    kind                misc, compliment     310C
# 2961               legendary                misc, compliment     320C
# 2962                loveable                misc, compliment     330C
# 2963                 magical                misc, compliment     340W
# 2964               masterful                misc, compliment     350W
# 2966                powerful                misc, compliment     370C
# 2968                 soulful                misc, compliment     390N
# 2969                spirited                misc, compliment     400C
# 2970                  strong                misc, compliment     410W
# 2972                 warrior                misc, compliment     430N
# 2973                    wise                misc, compliment     440C
# 4887                reverent                misc, compliment     RG75
# 4888                 magical                misc, compliment     RG80
# 4889             unstoppable                misc, compliment     RG85
#
#           hex  lightness
# 590   #835839   0.368627
# 601   #835839   0.368627
# 614   #835839   0.368627
# 624   #835839   0.368627
# 962   #CF9C74   0.633333
# 963   #D8A272   0.647059
# 1235  #D69B63   0.613725
# 1257  #C49474   0.611765
# 1407  #CB9773   0.623529
# 1430  #C09982   0.631373
# 1435  #9E754F   0.464706
# 1606  #A4704B   0.468627
# 1608  #C5987A   0.625490
# 1707  #CA8B5F   0.582353
# 1708  #C29679   0.617647
# 1737  #C2743C   0.498039
# 1811  #CD8B47   0.541176
# 1826  #D19C7A   0.649020
# 1920  #C39976   0.613725
# 1933  #CF9876   0.637255
# 2022  #B28F71   0.570588
# 2054  #D1A874   0.637255
# 2142  #DBA472   0.652941
# 2144  #D6A878   0.654902
# 2688  #D99E68   0.629412
# 2789  #DCA86F   0.649020
# 2887  #C29172   0.603922
# 2953  #D99A64   0.621569
# 2955  #DD985F   0.619608
# 2956  #D38D53   0.576471
# 2957  #D28D53   0.574510
# 2958  #DA7F3D   0.547059
# 2959  #CE7F49   0.547059
# 2960  #C57341   0.513725
# 2961  #CD6D38   0.511765
# 2962  #CD6D38   0.511765
# 2963  #C5692E   0.476471
# 2964  #A94D1D   0.388235
# 2966  #C96B38   0.503922
# 2968  #A1411F   0.376471
# 2969  #9F4221   0.376471
# 2970  #76301B   0.284314
# 2972  #57241C   0.225490
# 2973  #452722   0.201961
# 4887  #A97F6B   0.541176
# 4888  #9E715F   0.496078
# 4889  #8F6459   0.454902

# %% [markdown]
# #### Brands & shade range

# %% [markdown]
# shows the distribution/range of shades for the top and bottom 5 brands (in terms of how many shades they have)

# %%
shadesdf[['brand','lightness']]
# Out:
#                         brand  lightness
# 0     Anastasia Beverly Hills   0.458824
# 1     Anastasia Beverly Hills   0.901961
# 2     Anastasia Beverly Hills   0.900000
# 3     Anastasia Beverly Hills   0.809804
# 4     Anastasia Beverly Hills   0.750980
# ...                       ...        ...
# 6811                  Lancôme   0.645098
# 6812                  Antonym   0.654902
# 6813        Benefit Cosmetics   0.609804
# 6814    Urban Decay Cosmetics   0.507843
# 6815             bareMinerals   0.513725
#
# [6816 rows x 2 columns]

# %%
shadesdf.groupby('brand')['brand'].count()
# Out:
# brand
# AMOREPACIFIC                 5
# Almay                       20
# Anastasia Beverly Hills     54
# Antonym                      7
# Armani Beauty              129
#                           ...
# florence by mills           15
# jane iredale                57
# lilah b.                     5
# rms beauty                  32
# surratt beauty              14
# Name: brand, Length: 107, dtype: int64

# %%
shadesdf.groupby('brand')['brand'].count().sort_values(ascending=False)[-10:]
# Out:
# brand
# AMOREPACIFIC                 5
# Winky Lux                    4
# Dr. Jart+                    4
# boscia                       4
# Erborian                     4
# COOLA                        3
# Marc Jacobs Beauty           3
# Dr. Dennis Gross Skincare    2
# KIKO Milano                  2
# Black Up                     1
# Name: brand, dtype: int64

# %%
brand = list(shadesdf.groupby('brand')['brand'].count().sort_values(ascending=False)[-10:].index)

# %%
shadesdf.loc[shadesdf['brand']==brand[1]].plot(kind='box',y='lightness')
# Out:
# <AxesSubplot:>

# %%
shadesdf[['brand','lightness']].boxplot(by='brand')
# Out:
# <AxesSubplot:title={'center':'lightness'}, xlabel='[brand]'>

# %%
#brands = shadesdf.brand.unique()
#brandsdf = pd.DataFrame(brands, columns = ['brand'])
#brands
#shadesdf.loc[shadesdf['brand']] == 'Antonym'

# %% [markdown]
# I would like to create visualizations that
# 1) shows the distribution of shades across categories. I would like to explore if any particular term is more frequently used for certain shades.
# 2) shows the distribution/range of shades for each brand. This will allow us to see what brands have a wide/narrow range of shades.
# 3) incorporates VADER to classify sentiments. I could potentially gather reviews of different foundations & shades and use VADER to assess their sentiments. I could create a visualization using the polarity scores. *professor recommends not to*
# 4) reflects the diversity/creatvity in naming different tones of shades. The article talks about how there are limited words when it comes to naming darker tones, so I would like to make a visualization which shows the range of diversity in names of different shades.

# %% [markdown]
# ## DISCUSSION

# %% [markdown]
# ## What I'm planning on doing (03.11.22)

# %% [markdown]
# - adding more information in the intro & method section about background info + how the Pudding got their data
# - visualization for the range of shades for different brands
# - adding analyses for visualizations
# - write the discussion section about the project
